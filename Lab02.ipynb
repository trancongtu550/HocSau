# %% [markdown]
# <a href="https://colab.research.google.com/github/187it20961/PTDL-HS/blob/main/Lab02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("https://raw.githubusercontent.com/Hung621/DataAnalystDeepLearning/main/Lab01/processed_dulieuxettuyendaihoc.csv", index_col= "STT")

# %%
print(df)
# Out:
#       T1   L1   H1   S1   V1   X1  ...  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# STT                                ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  ...    K    K    2.800    3.016    2.804   rớt
# 2    5.4  3.9  3.9  4.0  5.4  5.4  ...   TB   TB    1.876    2.188    2.028   rớt
# 3    5.6  6.8  7.2  7.5  4.3  7.4  ...   TB   TB    2.308    2.152    2.416   đậu
# 4    6.6  6.4  5.3  6.9  5.4  7.3  ...   TB    K    2.484    2.080    2.752   rớt
# 5    6.0  5.0  6.0  7.3  6.5  7.7  ...   TB    K    2.600    2.544    2.796   rớt
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...      ...      ...      ...   ...
# 96   8.6  6.9  7.4  8.8  7.6  5.8  ...    K    K    2.972    2.968    2.732   rớt
# 97   3.7  5.4  6.0  5.1  5.5  3.9  ...   TB   TB    1.972    2.060    2.556   rớt
# 98   8.8  5.5  7.4  7.7  6.2  7.3  ...    K    K    2.820    3.136    3.068   đậu
# 99   2.7  1.8  3.4  5.3  4.5  7.9  ...    Y   TB    1.660    1.888    2.116   rớt
# 100  4.1  5.2  4.9  5.3  5.5  5.4  ...   TB   TB    2.104    2.288    2.340   rớt
#
# [100 rows x 65 columns]

# %% [markdown]
# **Phần 1 :** Thống kê dữ liệu

# %% [markdown]
# 1.Hãy sắp xếp dữ liệu điểm DH1 theo thứ tự tăng dần

# %%
print(df.sort_values(by='DH1'))
# Out:
#       T1   L1   H1   S1   V1   X1  ...  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# STT                                ...
# 54   4.9  5.9  6.2  5.6  5.9  5.0  ...   TB   TB    2.276    2.504    2.408   rớt
# 44   6.6  7.2  5.9  6.9  7.6  8.1  ...    K    K    2.820    2.644    2.708   rớt
# 73   5.5  6.6  7.2  7.6  5.5  6.7  ...   TB   TB    2.480    2.352    2.488   rớt
# 6    9.3  7.6  7.9  8.6  7.0  7.3  ...    G    K    3.184    3.416    2.952   rớt
# 88   7.3  4.3  5.3  5.8  4.9  3.7  ...   TB   TB    2.176    2.312    2.592   rớt
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...      ...      ...      ...   ...
# 85   8.4  7.4  6.0  7.8  6.3  7.2  ...    K    K    2.892    3.108    3.032   đậu
# 12   7.9  7.0  9.1  8.6  6.1  7.0  ...    K    K    2.972    3.088    2.996   đậu
# 24   5.3  6.3  5.7  6.9  5.9  7.5  ...   TB    K    2.420    2.528    2.684   đậu
# 25   2.4  4.1  3.6  5.5  5.9  5.6  ...    Y   TB    1.780    1.952    2.164   rớt
# 98   8.8  5.5  7.4  7.7  6.2  7.3  ...    K    K    2.820    3.136    3.068   đậu
#
# [100 rows x 65 columns]

# %% [markdown]
# 2.Hãy sắp xếp dữ liệu điểm DH2 tăng dần theo nhóm giới tính

# %%
print(df.sort_values(by=['GT','DH2']))
# Out:
#       T1   L1   H1   S1   V1   X1  ...  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# STT                                ...
# 96   8.6  6.9  7.4  8.8  7.6  5.8  ...    K    K    2.972    2.968    2.732   rớt
# 26   3.6  5.8  6.9  6.1  5.5  7.2  ...   TB   TB    2.160    2.080    2.036   rớt
# 25   2.4  4.1  3.6  5.5  5.9  5.6  ...    Y   TB    1.780    1.952    2.164   rớt
# 47   6.7  6.8  6.4  5.9  5.6  6.4  ...    K   TB    2.596    2.604    2.464   rớt
# 14   4.9  5.4  5.0  5.0  5.8  7.0  ...   TB   TB    2.152    2.204    2.504   rớt
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...      ...      ...      ...   ...
# 69   7.3  6.4  6.9  7.5  6.2  8.4  ...    K    G    2.876    3.080    3.200   rớt
# 12   7.9  7.0  9.1  8.6  6.1  7.0  ...    K    K    2.972    3.088    2.996   đậu
# 48   7.9  7.6  8.4  8.6  6.2  7.5  ...    K    K    3.068    2.996    2.844   đậu
# 3    5.6  6.8  7.2  7.5  4.3  7.4  ...   TB   TB    2.308    2.152    2.416   đậu
# 98   8.8  5.5  7.4  7.7  6.2  7.3  ...    K    K    2.820    3.136    3.068   đậu
#
# [100 rows x 65 columns]

# %% [markdown]
# 3.Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, std, Q1, Q2 và Q3 của DH1 theo KT

# %%
def Q1(g):
  return np.percentile(g,25)

def Q2(g):
  return np.percentile(g,50)

def Q3(g):
  return np.percentile(g,75)

def std(g):
  return np.std(g)

pivot_table_KT = pd.pivot_table(data=df, index='KT',values='DH1', aggfunc=['sum','mean','median','min','max',std,Q1,Q2,Q3])
print(pivot_table_KT)
# Out:
#        sum      mean median   min   max       std      Q1    Q2     Q3
#        DH1       DH1    DH1   DH1   DH1       DH1     DH1   DH1    DH1
# KT
# A   163.50  3.336735   3.25  1.00  6.50  1.261226  2.2500  3.25  4.250
# A1   17.50  2.916667   3.00  2.00  4.25  0.786165  2.1875  3.00  3.250
# B    29.50  3.277778   3.50  1.75  4.50  0.776785  3.2500  3.50  3.750
# C    79.25  5.660714   5.25  4.75  7.00  0.782665  5.0625  5.25  6.375
# D1   84.25  3.829545   3.75  1.25  6.75  1.338644  3.0000  3.75  4.875

# %% [markdown]
# 4.Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, std, Q1, Q2 và Q3 của DH1 theo KT và KV

# %%
def Q1(g):
  return np.percentile(g,25)

def Q2(g):
  return np.percentile(g,50)

def Q3(g):
  return np.percentile(g,75)

def std(g):
  return np.std(g)

pivot_table_KT_KV = pd.pivot_table(data=df, index=['KT','KV'],values='DH1', aggfunc=['sum','mean','median','min','max',std,Q1,Q2,Q3])
print(pivot_table_KT_KV)
# Out:
#           sum      mean median   min   max       std      Q1     Q2      Q3
#           DH1       DH1    DH1   DH1   DH1       DH1     DH1    DH1     DH1
# KT KV
# A  1    93.75  3.232759  3.250  1.00  6.50  1.345380  2.0000  3.250  4.2500
#    2    31.75  3.527778  3.500  2.00  6.25  1.346005  2.2500  3.500  4.2500
#    2NT  38.00  3.454545  3.500  2.00  4.75  0.871377  2.8750  3.500  4.1250
# A1 1     4.75  2.375000  2.375  2.00  2.75  0.375000  2.1875  2.375  2.5625
#    2NT  12.75  3.187500  3.250  2.00  4.25  0.797947  2.9375  3.250  3.5000
# B  1    25.75  3.218750  3.375  1.75  4.50  0.804650  3.0000  3.375  3.5625
#    2NT   3.75  3.750000  3.750  3.75  3.75  0.000000  3.7500  3.750  3.7500
# C  1    43.50  5.437500  5.250  4.75  7.00  0.681795  5.0000  5.250  5.4375
#    2    11.50  5.750000  5.750  5.00  6.50  0.750000  5.3750  5.750  6.1250
#    2NT  24.25  6.062500  6.000  5.25  7.00  0.817294  5.2500  6.000  6.8125
# D1 1    46.75  3.596154  3.500  1.50  5.75  1.215044  2.7500  3.500  4.2500
#    2    33.75  4.218750  4.500  1.25  6.75  1.512642  3.5625  4.500  5.0000
#    2NT   3.75  3.750000  3.750  3.75  3.75  0.000000  3.7500  3.750  3.7500

# %% [markdown]
# 5.Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, sdt, Q1, Q2 và Q3 của DH1 theo KT, KV và DT

# %%
def Q1(g):
  return np.percentile(g,25)

def Q2(g):
  return np.percentile(g,50)

def Q3(g):
  return np.percentile(g,75)

def std(g):
  return np.std(g)

pivot_table_KT_KV_DT = pd.pivot_table(data=df, index=['KT','KV','DT'],values='DH1', aggfunc=['sum','mean','median','min','max',std,Q1,Q2,Q3])
print(pivot_table_KT_KV_DT)
# Out:
#               sum      mean median   min   max       std      Q1     Q2      Q3
#               DH1       DH1    DH1   DH1   DH1       DH1     DH1    DH1     DH1
# KT KV  DT
# A  1   0.0  93.75  3.232759  3.250  1.00  6.50  1.345380  2.0000  3.250  4.2500
#    2   0.0  27.50  3.437500  3.000  2.00  6.25  1.401729  2.2500  3.000  4.1875
#        6.0   4.25  4.250000  4.250  4.25  4.25  0.000000  4.2500  4.250  4.2500
#    2NT 0.0  38.00  3.454545  3.500  2.00  4.75  0.871377  2.8750  3.500  4.1250
# A1 1   0.0   4.75  2.375000  2.375  2.00  2.75  0.375000  2.1875  2.375  2.5625
#    2NT 0.0  12.75  3.187500  3.250  2.00  4.25  0.797947  2.9375  3.250  3.5000
# B  1   0.0  25.75  3.218750  3.375  1.75  4.50  0.804650  3.0000  3.375  3.5625
#    2NT 0.0   3.75  3.750000  3.750  3.75  3.75  0.000000  3.7500  3.750  3.7500
# C  1   0.0  43.50  5.437500  5.250  4.75  7.00  0.681795  5.0000  5.250  5.4375
#    2   0.0  11.50  5.750000  5.750  5.00  6.50  0.750000  5.3750  5.750  6.1250
#    2NT 0.0  24.25  6.062500  6.000  5.25  7.00  0.817294  5.2500  6.000  6.8125
# D1 1   0.0  43.75  3.645833  3.625  1.50  5.75  1.251908  2.6875  3.625  4.4375
#        1.0   3.00  3.000000  3.000  3.00  3.00  0.000000  3.0000  3.000  3.0000
#    2   0.0  32.50  4.642857  4.500  3.00  6.75  1.084445  4.1250  4.500  5.0000
#        1.0   1.25  1.250000  1.250  1.25  1.25  0.000000  1.2500  1.250  1.2500
#    2NT 0.0   3.75  3.750000  3.750  3.75  3.75  0.000000  3.7500  3.750  3.7500

# %% [markdown]
# **Phần 2 :** Trình bày dữ liệu

# %% [markdown]
# 1.Hãy trình bày dữ liệu biến: GT

# %%
pd.pivot_table(df.groupby('GT')['GT'].agg(['count']),columns='GT').plot.bar(stacked=True)

# %%
df.groupby('GT')['GT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa60a3cff50>],
#       dtype=object)

# %% [markdown]
# 2.Hãy trình bày dữ liệu lần lượt các biến: US_TBM1, US_TBM2 và US_TBM3

# %%
df['US_TBM1'].plot.hist(bins=20)
plt.xlabel('Diem_US_TBM1')
# Out:
# Text(0.5, 0, 'Diem_US_TBM1')

# %%
df['US_TBM2'].plot.hist(bins=20)
plt.xlabel('Diem_US_TBM2')
# Out:
# Text(0.5, 0, 'Diem_US_TBM2')

# %%
df['US_TBM3'].plot.hist(bins=20)
plt.xlabel('Diem_US_TBM3')
# Out:
# Text(0.5, 0, 'Diem_US_TBM3')

# %% [markdown]
# 3.Hãy trình bày dữ liệu biến DT với các học sinh là nam

# %%
df.loc[df['GT'] == 'M'].groupby('DT')['DT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa609d19d50>],
#       dtype=object)

# %% [markdown]
# 4.Hãy trình bày dữ liệu biến KV với các học sinh là nam thuộc dân tộc Kinh, có điểm thỏa mãn điều kiện (DH1 >= 5.0 và DH2 >= 4.0 và DH3 >= 4.0)

# %%
df.loc[(df['GT'] == 'M') & (df['DT'] == 0) & (df['DH1'] >= 5) & (df['DH2'] >= 4) & (df['DH3'] >= 4)].groupby('KV')['KV'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa609c87fd0>],
#       dtype=object)

# %% [markdown]
# 5.Hãy trình bày dữ liệu lần lượt các biến DH1, DH2, DH3 lớn hơn bằng 5.0 và thuộc khu vực 2NT

# %%
df['DH1'].loc[(df['DH1'] >= 5) & (df['KV'] == '2NT')].plot.hist(bins=20)
plt.xlabel('DiemTDH_DH1')
plt.ylabel('SL')
# Out:
# Text(0, 0.5, 'SL')

# %%
df['DH2'].loc[(df['DH2'] >= 5) & (df['KV'] == '2NT')].plot.hist(bins=20)
plt.xlabel('DiemTDH_DH2')
plt.ylabel('SL')
# Out:
# Text(0, 0.5, 'SL')

# %%
df['DH3'].loc[(df['DH3'] >= 5) & (df['KV'] == '2NT')].plot.hist(bins=20)
plt.xlabel('DiemTDH_DH3')
plt.ylabel('SL')
# Out:
# Text(0, 0.5, 'SL')

# %% [markdown]
# **Phần 3:** Trực quan hóa dữ liệu theo nhóm phân loại

# %% [markdown]
# 1.Trực quan dữ liệu học sinh nữ trên các nhóm XL1, XL2, XL3 dạng unstacked

# %%
pd.pivot_table(df.loc[df['GT'] == 'F'].groupby(['XL1'])['GT'].agg(['count']),columns='XL1').plot.bar(stacked=False)
plt.xlabel('XL1')
plt.ylabel('SLXL')
# Out:
# Text(0, 0.5, 'SLXL')

# %%
pd.pivot_table(df.loc[df['GT'] == 'F'].groupby(['XL2'])['GT'].agg(['count']),columns='XL2').plot.bar(stacked=False)
plt.xlabel('XL2')
plt.ylabel('SLXL')
# Out:
# Text(0, 0.5, 'SLXL')

# %%
pd.pivot_table(df.loc[df['GT'] == 'F'].groupby(['XL3'])['GT'].agg(['count']),columns='XL3').plot.bar(stacked=False)
plt.xlabel('XL3')
plt.ylabel('SLXL')
# Out:
# Text(0, 0.5, 'SLXL')

# %% [markdown]
# 2.Trực quan dữ liệu KQXT trên nhóm học sinh có khối thi A, A1, B thuộc khu vực 1, 2

# %%
Thuoc_KV = df.loc[(df['KV'] == '1')].append(df.loc[(df['KV'] == '2')])
DK_KT = Thuoc_KV.loc[(Thuoc_KV['KT'] == 'A') | (Thuoc_KV['KT'] == 'A1') | (Thuoc_KV['KT'] == 'B')]
DK_KT.groupby('KQXT')['KT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6098c4750>],
#       dtype=object)

# %% [markdown]
# 3.Trực quan dữ liệu số lượng thí sinh từng khu vực dựa trên từng nhóm khối thi

# %%
df.loc[df['KT'] == 'A'].groupby('KV')['KT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
plt.xlabel('KT A')
# Out:
# Text(0.5, 0, 'KT A')

# %%
df.loc[df['KT'] == 'A1'].groupby('KV')['KT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
plt.xlabel('KT A1')
# Out:
# Text(0.5, 0, 'KT A1')

# %%
df.loc[df['KT'] == 'B'].groupby('KV')['KT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
plt.xlabel('KT B')
# Out:
# Text(0.5, 0, 'KT B')

# %%
df.loc[df['KT'] == 'C'].groupby('KV')['KT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
plt.xlabel('KT C')
# Out:
# Text(0.5, 0, 'KT C')

# %%
df.loc[df['KT'] == 'D1'].groupby('KV')['KT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
plt.xlabel('KT D1')
# Out:
# Text(0.5, 0, 'KT D1')

# %% [markdown]
# 4.Trực quan dữ liệu số lượng thí sinh đậu, rớt trên từng nhóm khối thi

# %%
df.loc[df['KT'] == 'A'].groupby('KQXT')['KT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa609681190>],
#       dtype=object)

# %%
df.loc[df['KT'] == 'A1'].groupby('KQXT')['KT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa609671cd0>],
#       dtype=object)

# %%
df.loc[df['KT'] == 'B'].groupby('KQXT')['KT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6095a5990>],
#       dtype=object)

# %%
df.loc[df['KT'] == 'C'].groupby('KQXT')['KT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa609577290>],
#       dtype=object)

# %%
df.loc[df['KT'] == 'D1'].groupby('KQXT')['KT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa609553190>],
#       dtype=object)

# %% [markdown]
# 5.Trực quan dữ liệu số lượng thí sinh đậu rớt trên từng nhóm khu vực.

# %%
df.loc[df['KV'] == '1'].groupby('KQXT')['KV'].agg('count').plot.pie(subplots=True,autopct='%.2f %%')
plt.legend()

# %%
df.loc[df['KV'] == '2'].groupby('KQXT')['KV'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6095a5290>],
#       dtype=object)

# %%
df.loc[df['KV'] == '2NT'].groupby('KQXT')['KV'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6111cb550>],
#       dtype=object)

# %% [markdown]
# 6.Trực quan dữ liệu số lượng thí sinh đậu rớt dựa trên từng nhóm dân tộc

# %%
df.loc[df['DT'] == 0].groupby('KQXT')['DT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa60970b810>],
#       dtype=object)

# %%
df.loc[df['DT'] == 1].groupby('KQXT')['DT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa60964ef10>],
#       dtype=object)

# %%
df.loc[df['DT'] == 6].groupby('KQXT')['DT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa609328610>],
#       dtype=object)

# %% [markdown]
# 7.Trực quan dữ liệu số lượng thí sinh đậu rớt dựa trên từng nhóm giới tính.

# %%
df.loc[df['GT'] == 'M'].groupby('KQXT')['GT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6093a1310>],
#       dtype=object)

# %%
df.loc[df['GT'] == 'F'].groupby('KQXT')['GT'].agg(['count']).plot.pie(subplots=True,autopct='%.2f %%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6092ca5d0>],
#       dtype=object)

# %% [markdown]
# **Phần 4:** Trực quan hóa dữ liệu nâng cao

# %% [markdown]
# 1.Vẽ biểu đồ đường Simple cho biến T1

# %%
df.groupby('T1')['T1'].agg('count').plot()

# %% [markdown]
# 2.Hãy tạo biến phân loại (phanlopt1) cho môn toán (T1) như sau:
# - Từ 0 đến dưới 5 = kém (ký hiệu "k").
# - Từ 5 đến dưới 7 = trung bình (ký hiệu "tb")
# - Từ 7 đến dưới 8 = khá (ký hiệu "kh")
# - Từ 8 trở lên = giỏi (ký hiệu "g")

# %%
for i in df['T1']:
  df.loc[(df['T1'] >= 0) & (df['T1'] < 5), 'phanlopt1'] = 'k'
  df.loc[(df['T1'] >= 5) & (df['T1'] < 7), 'phanlopt1'] = 'tb'
  df.loc[(df['T1'] >= 7) & (df['T1'] < 8), 'phanlopt1'] = 'kh'
  df.loc[(df['T1'] >= 8), 'phanlopt1'] = 'g'

# %%
print(df)
# Out:
#       T1   L1   H1   S1   V1   X1  ...  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT  phanlopt1
# STT                                ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  ...    K    2.800    3.016    2.804   rớt         kh
# 2    5.4  3.9  3.9  4.0  5.4  5.4  ...   TB    1.876    2.188    2.028   rớt         tb
# 3    5.6  6.8  7.2  7.5  4.3  7.4  ...   TB    2.308    2.152    2.416   đậu         tb
# 4    6.6  6.4  5.3  6.9  5.4  7.3  ...    K    2.484    2.080    2.752   rớt         tb
# 5    6.0  5.0  6.0  7.3  6.5  7.7  ...    K    2.600    2.544    2.796   rớt         tb
# ..   ...  ...  ...  ...  ...  ...  ...  ...      ...      ...      ...   ...        ...
# 96   8.6  6.9  7.4  8.8  7.6  5.8  ...    K    2.972    2.968    2.732   rớt          g
# 97   3.7  5.4  6.0  5.1  5.5  3.9  ...   TB    1.972    2.060    2.556   rớt          k
# 98   8.8  5.5  7.4  7.7  6.2  7.3  ...    K    2.820    3.136    3.068   đậu          g
# 99   2.7  1.8  3.4  5.3  4.5  7.9  ...   TB    1.660    1.888    2.116   rớt          k
# 100  4.1  5.2  4.9  5.3  5.5  5.4  ...   TB    2.104    2.288    2.340   rớt          k
#
# [100 rows x 66 columns]

# %% [markdown]
# 3.Lập bảng tần số cho biến phanloait1

# %%
tanso_phanloait1 = df.groupby('phanlopt1')['phanlopt1'].agg(['count'])
pd.pivot_table(tanso_phanloait1,columns='phanlopt1')
# Out:
# phanlopt1   g   k  kh  tb
# count      12  23  19  46

# %% [markdown]
# 4.Vẽ biểu đồ đường Multiple Line cho biến T1 được phân loại bởi biến phanlopt1

# %%
sales1 = df['T1'].loc[df['phanlopt1'] == 'k']
sales2 = df['T1'].loc[df['phanlopt1'] == 'tb']
sales3 = df['T1'].loc[df['phanlopt1'] == 'kh']
sales4 = df['T1'].loc[df['phanlopt1'] == 'g']
df.groupby(sales1)['phanlopt1'].agg('count').plot(label="k")
df.groupby(sales2)['phanlopt1'].agg('count').plot(label="tb")
df.groupby(sales3)['phanlopt1'].agg('count').plot(label="kh")
df.groupby(sales4)['phanlopt1'].agg('count').plot(label="g")
plt.legend()

# %% [markdown]
# Vẽ biểu đồ Drop-line cho biến T1 được phân loại bởi biến phanlopt1

# %% [markdown]
# Hãy mô tả và khảo sát phân phối cho biến T1

# %%
df['T1'].plot.box()

# %%
df['T1'].plot.hist()
plt.xlabel('T1')
# Out:
# Text(0.5, 0, 'T1')

# %% [markdown]
# 5.Hãy mô tả và khảo sát phân phối cho biến T1 trên từng nhóm phân lớp (phanlopt1)

# %%
df.groupby('phanlopt1')['phanlopt1'].agg(['count']).plot.box()

# %%
pd.pivot_table(df.groupby('phanlopt1')['phanlopt1'].agg(['count']),columns='phanlopt1').plot.hist()
plt.legend()

# %%
import statsmodels.api as sm
sm.qqplot(df.groupby('phanlopt1')['phanlopt1'].agg(['count']), line ='45')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Hãy khảo sát tương quan giữa biến DH1 theo biến T1

# %%
df.plot.scatter(x='DH1',y='T1')

# %% [markdown]
# Hãy khảo sát tương quan giữa biến DH1 theo biến T1 trên từng nhóm khu vực

# %%
df.loc[df['KV'] == '1'].plot.scatter(x='DH1',y='T1')

# %%
df.loc[df['KV'] == '2'].plot.scatter(x='DH1',y='T1')

# %%
df.loc[df['KV'] == '2NT'].plot.scatter(x='DH1',y='T1')

# %% [markdown]
# Hãy khảo sát tương quan giữa các biến DH1, DH2, DH3

# %%
df.plot.scatter(x='DH1',y='DH2')

# %%
df.plot.scatter(x='DH1',y='DH3')

# %%
df.plot.scatter(x='DH2',y='DH3')
